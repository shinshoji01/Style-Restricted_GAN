# %%
import numpy as np
import pandas as pd
import os
import glob

# %%
import sys
sys.path.append("../pyfiles/")
from util import pickle_load

# %%
fe_list = ["vgg-initialization", "vgg-ImageNet", "vgg-CelebA"]
metrics = ["precision", "recall", "density", "coverage"]
classes = tuple(range(4))

# %%
path_list = glob.glob("../data/results/*/*GAN_evaluation*")
path_list.sort()

model_name = []
for path in path_list:
    model_name.append(os.path.basename(path)[:-4])
path_list
# Out:
# ['../data/results/01/01_GAN_evaluation_cycle10_idt1.pkl',
#  '../data/results/01/01_GAN_evaluation_cycle5_idt5.pkl',
#  '../data/results/02/02_GAN_evaluation_cycle10_idt1.pkl',
#  '../data/results/02/02_GAN_evaluation_cycle5_idt5.pkl',
#  '../data/results/03/03_GAN_evaluation_conventionalKL.pkl',
#  '../data/results/03/03_GAN_evaluation_proposedKL.pkl',
#  '../data/results/03/03_GAN_evaluation_styleINdataset_conventionalKL.pkl',
#  '../data/results/03/03_GAN_evaluation_styleINdataset_proposedKL.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relu_0.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relu_attention0_consisreg0.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relu_attention0_consisreg10.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relumodified_attention10000_consisreg0.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relumodified_attention1000_consisreg0.pkl',
#  '../data/results/05/05_GAN_evaluation_gradattention_relumodified_attention1000_consisreg1.pkl',
#  '../data/results/05/05_GAN_evaluation_nostyleINdataset_pretrained__attention0_consisreg0.pkl',
#  '../data/results/05/05_GAN_evaluation_pretrained_relu_attention0_consisreg0.pkl',
#  '../data/results/05/05_GAN_evaluation_pretrained_relumodified_attention0_consisreg1.pkl']

# %%
source_label = 3
target_label = 2
model_idx = 0

print(model_name[model_idx])
GAN_eval = pickle_load(path_list[model_idx])
scores = []
for fe in fe_list:
    for metric in metrics:
        scores.append(np.mean(GAN_eval[fe][source_label][target_label][metric]))
pd.DataFrame(np.array(scores).reshape(len(fe_list),4), index=fe_list, columns=metrics)
# Out:
# 01_GAN_evaluation_cycle10_idt1
#                     precision   recall   density  coverage
# vgg-initialization    0.73819  0.00000  0.599926   0.00581
# vgg-ImageNet          0.61490  0.00000  0.633982   0.01782
# vgg-CelebA            0.99060  0.02572  0.999272   0.06097

# %%
fe = fe_list[0]
metric = "coverage"
model_idx = 0

print(fe)
print(model_name[model_idx])
GAN_eval = pickle_load(path_list[model_idx])
scores = []
for source_label in classes:
    for target_label in classes:
        scores.append(np.mean(GAN_eval[fe][source_label][target_label][metric]))
pd.DataFrame(np.array(scores).reshape(4,4), index=classes, columns=classes)
# Out:
# vgg-initialization
# 01_GAN_evaluation_cycle10_idt1
#          0        1        2        3
# 0  0.00789  0.00791  0.00725  0.00970
# 1  0.00457  0.00731  0.00552  0.00680
# 2  0.01063  0.01215  0.00956  0.01160
# 3  0.00653  0.00829  0.00581  0.00909

# %% [markdown]
# ---
# - score among selected classes with a selected model type
#
# ---

# %%
source_label = 3
target_label = 2
fe = fe_list[2]

print(fe)
scores = []
for path in path_list:
    GAN_eval = pickle_load(path)
    for metric in metrics:
        scores.append(np.mean(GAN_eval[fe][source_label][target_label][metric]))
pd.DataFrame(np.array(scores).reshape(len(path_list),4), index=model_name, columns=metrics)
# Out:
# vgg-CelebA
#                                                     precision   recall  \
# 01_GAN_evaluation_cycle10_idt1                        0.99060  0.02572
# 01_GAN_evaluation_cycle5_idt5                         0.98711  0.03180
# 02_GAN_evaluation_cycle10_idt1                        0.99649  0.01238
# 02_GAN_evaluation_cycle5_idt5                         0.99787  0.01335
# 03_GAN_evaluation_conventionalKL                      0.98948  0.00834
# 03_GAN_evaluation_proposedKL                          0.99384  0.14883
# 03_GAN_evaluation_styleINdataset_conventionalKL       1.00000  0.00000
# 03_GAN_evaluation_styleINdataset_proposedKL           0.99109  0.08743
# 05_GAN_evaluation_gradattention_relu_0                0.99289  0.18703
# 05_GAN_evaluation_gradattention_relu_attention0...    0.99294  0.24190
# 05_GAN_evaluation_gradattention_relu_attention0...    0.99371  0.30803
# 05_GAN_evaluation_gradattention_relumodified_at...    0.99650  0.09638
# 05_GAN_evaluation_gradattention_relumodified_at...    0.99401  0.11434
# 05_GAN_evaluation_gradattention_relumodified_at...    0.99554  0.09288
# 05_GAN_evaluation_nostyleINdataset_pretrained__...    0.99453  0.32016
# 05_GAN_evaluation_pretrained_relu_attention0_co...    0.99299  0.21533
# 05_GAN_evaluation_pretrained_relumodified_atten...    0.99425  0.32466
#
#                                                      density  coverage
# 01_GAN_evaluation_cycle10_idt1                      0.999272   0.06097
# 01_GAN_evaluation_cycle5_idt5                       1.046208   0.06915
# 02_GAN_evaluation_cycle10_idt1                      0.996114   0.04172
# 02_GAN_evaluation_cycle5_idt5                       0.999646   0.04480
# 03_GAN_evaluation_conventionalKL                    1.053238   0.03130
# 03_GAN_evaluation_proposedKL                        0.989042   0.17812
# 03_GAN_evaluation_styleINdataset_conventionalKL     1.088818   0.00557
# 03_GAN_evaluation_styleINdataset_proposedKL         0.988702   0.15846
# 05_GAN_evaluation_gradattention_relu_0              1.020384   0.25579
# 05_GAN_evaluation_gradattention_relu_attention0...  1.005416   0.26357
# 05_GAN_evaluation_gradattention_relu_attention0...  1.020108   0.32166
# 05_GAN_evaluation_gradattention_relumodified_at...  1.044712   0.16448
# 05_GAN_evaluation_gradattention_relumodified_at...  1.028284   0.20024
# 05_GAN_evaluation_gradattention_relumodified_at...  1.022266   0.18779
# 05_GAN_evaluation_nostyleINdataset_pretrained__...  1.020186   0.38889
# 05_GAN_evaluation_pretrained_relu_attention0_co...  1.007326   0.31400
# 05_GAN_evaluation_pretrained_relumodified_atten...  1.021774   0.38564

# %% [markdown]
# ---
# - average score among classes with a selected model type
#
# ---

# %%
fe = fe_list[0]
print(fe)

all_score = []
for source_label in classes:
    for target_label in classes:
        scores = []
        for path in path_list:
            GAN_eval = pickle_load(path)
            for metric in metrics:
                scores.append(np.mean(GAN_eval[fe][source_label][target_label][metric]))
        all_score.append(np.array(scores).reshape(len(path_list), 4))
pd.DataFrame(np.mean(np.array(all_score), axis=0), index=model_name, columns=metrics)
# Out:
# vgg-initialization
#                                                     precision    recall  \
# 01_GAN_evaluation_cycle10_idt1                       0.849507  0.000000
# 01_GAN_evaluation_cycle5_idt5                        0.830858  0.000000
# 02_GAN_evaluation_cycle10_idt1                       0.846873  0.000000
# 02_GAN_evaluation_cycle5_idt5                        0.821443  0.000000
# 03_GAN_evaluation_conventionalKL                     0.835763  0.000000
# 03_GAN_evaluation_proposedKL                         0.851789  0.001673
# 03_GAN_evaluation_styleINdataset_conventionalKL      0.859052  0.000000
# 03_GAN_evaluation_styleINdataset_proposedKL          0.865989  0.000298
# 05_GAN_evaluation_gradattention_relu_0               0.859434  0.000000
# 05_GAN_evaluation_gradattention_relu_attention0...   0.856091  0.000000
# 05_GAN_evaluation_gradattention_relu_attention0...   0.868374  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.850594  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.849161  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.847826  0.000000
# 05_GAN_evaluation_pretrained_relu_attention0_co...   0.864818  0.000000
# 05_GAN_evaluation_pretrained_relumodified_atten...   0.877753  0.000000
#
#                                                      density  coverage
# 01_GAN_evaluation_cycle10_idt1                      0.811573  0.008163
# 01_GAN_evaluation_cycle5_idt5                       0.770116  0.007704
# 02_GAN_evaluation_cycle10_idt1                      0.877690  0.007176
# 02_GAN_evaluation_cycle5_idt5                       0.773683  0.006578
# 03_GAN_evaluation_conventionalKL                    0.818254  0.007101
# 03_GAN_evaluation_proposedKL                        0.818887  0.192123
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.940628  0.004729
# 03_GAN_evaluation_styleINdataset_proposedKL         0.910030  0.117006
# 05_GAN_evaluation_gradattention_relu_0              0.897795  0.008026
# 05_GAN_evaluation_gradattention_relu_attention0...  0.913073  0.008548
# 05_GAN_evaluation_gradattention_relu_attention0...  0.975741  0.009316
# 05_GAN_evaluation_gradattention_relumodified_at...  0.927103  0.008391
# 05_GAN_evaluation_gradattention_relumodified_at...  0.873284  0.007814
# 05_GAN_evaluation_gradattention_relumodified_at...  0.854735  0.007431
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.924520  0.010258
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.977387  0.010593

# %%
reference = np.array([False, False, False, False,
                      True, False, True, False,
                      False, False, False, False,
                      True, False, True, False])

# %%
fe = fe_list[0]
print(fe)

all_score = []
for source_label in classes:
    for target_label in classes:
        scores = []
        for path in path_list:
            GAN_eval = pickle_load(path)
            for metric in metrics:
                scores.append(np.mean(GAN_eval[fe][source_label][target_label][metric]))
        all_score.append(np.array(scores).reshape(len(path_list), 4))
pd.DataFrame(np.mean(np.array(all_score)[reference], axis=0), index=model_name, columns=metrics)
# Out:
# vgg-initialization
#                                                     precision    recall  \
# 01_GAN_evaluation_cycle5_idt5                        0.730090  0.000000
# 02_GAN_evaluation_cycle5_idt5                        0.695190  0.000000
# 03_GAN_evaluation_conventionalKL                     0.712692  0.000000
# 03_GAN_evaluation_proposedKL                         0.768873  0.000993
# 03_GAN_evaluation_styleINdataset_conventionalKL      0.756213  0.000000
# 03_GAN_evaluation_styleINdataset_proposedKL          0.766027  0.000315
# 05_GAN_evaluation_gradattention_relu_0               0.744328  0.000000
# 05_GAN_evaluation_gradattention_relu_attention0...   0.727333  0.000000
# 05_GAN_evaluation_gradattention_relu_attention0...   0.765457  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.733513  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.709295  0.000000
# 05_GAN_evaluation_gradattention_relumodified_at...   0.722988  0.000000
# 05_GAN_evaluation_pretrained_relu_attention0_co...   0.783092  0.000000
# 05_GAN_evaluation_pretrained_relumodified_atten...   0.786602  0.000000
#
#                                                      density  coverage
# 01_GAN_evaluation_cycle5_idt5                       0.546833  0.006073
# 02_GAN_evaluation_cycle5_idt5                       0.545769  0.004735
# 03_GAN_evaluation_conventionalKL                    0.529739  0.004685
# 03_GAN_evaluation_proposedKL                        0.609538  0.150425
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.640548  0.003218
# 03_GAN_evaluation_styleINdataset_proposedKL         0.654128  0.097568
# 05_GAN_evaluation_gradattention_relu_0              0.574651  0.005210
# 05_GAN_evaluation_gradattention_relu_attention0...  0.654167  0.006278
# 05_GAN_evaluation_gradattention_relu_attention0...  0.666896  0.006568
# 05_GAN_evaluation_gradattention_relumodified_at...  0.617769  0.005633
# 05_GAN_evaluation_gradattention_relumodified_at...  0.576895  0.005105
# 05_GAN_evaluation_gradattention_relumodified_at...  0.560488  0.004898
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.646775  0.007113
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.734147  0.007900

# %% [markdown]
# ---
# - score among models in a selected model type and metric
#
# ---

# %%
fe = fe_list[2]
metric = "coverage"

columns = []
for i in classes:
    for j in classes:
        columns.append((f"s:{i}", f"t:{j}"))
columns = pd.MultiIndex.from_tuples(columns)

scores = []
for path in path_list:
    GAN_eval = pickle_load(path)
    for source_label in classes:
        for target_label in classes:
            scores.append(np.round(np.mean(GAN_eval[fe][source_label][target_label][metric]),4))
pd.DataFrame(np.array(scores).reshape(len(path_list),16), index=model_name, columns=columns)
# Out:
#                                                        s:0                  \
#                                                        t:0     t:1     t:2
# 01_GAN_evaluation_cycle5_idt5                       0.0335  0.0552  0.0709
# 02_GAN_evaluation_cycle5_idt5                       0.0324  0.0443  0.0414
# 03_GAN_evaluation_conventionalKL                    0.0401  0.0299  0.0168
# 03_GAN_evaluation_proposedKL                        0.1979  0.2142  0.1601
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0053  0.0041  0.0025
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1384  0.1701  0.1071
# 05_GAN_evaluation_gradattention_relu_0              0.1814  0.1901  0.1872
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2263  0.2000  0.2167
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2315  0.1860  0.3149
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1298  0.1038  0.0875
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0943  0.0871  0.1738
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1112  0.1170  0.1304
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2452  0.2538  0.2672
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3087  0.2894  0.3685
#
#                                                                s:1          \
#                                                        t:3     t:0     t:1
# 01_GAN_evaluation_cycle5_idt5                       0.1004  0.0572  0.0275
# 02_GAN_evaluation_cycle5_idt5                       0.0537  0.0462  0.0298
# 03_GAN_evaluation_conventionalKL                    0.0133  0.0386  0.0339
# 03_GAN_evaluation_proposedKL                        0.2132  0.1955  0.2132
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0011  0.0052  0.0053
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1760  0.1763  0.1353
# 05_GAN_evaluation_gradattention_relu_0              0.2994  0.1918  0.1556
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2628  0.2371  0.1595
# 05_GAN_evaluation_gradattention_relu_attention0...  0.3220  0.2552  0.1535
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1852  0.1534  0.0944
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1958  0.1111  0.0716
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1738  0.1495  0.0922
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3784  0.2964  0.1698
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3466  0.3266  0.1738
#
#                                                                        s:2  \
#                                                        t:2     t:3     t:0
# 01_GAN_evaluation_cycle5_idt5                       0.0750  0.0533  0.0826
# 02_GAN_evaluation_cycle5_idt5                       0.0458  0.0308  0.0325
# 03_GAN_evaluation_conventionalKL                    0.0078  0.0172  0.0148
# 03_GAN_evaluation_proposedKL                        0.1411  0.1894  0.1002
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0019  0.0029  0.0031
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1159  0.1178  0.1300
# 05_GAN_evaluation_gradattention_relu_0              0.1819  0.2146  0.1928
# 05_GAN_evaluation_gradattention_relu_attention0...  0.1415  0.1792  0.2119
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2795  0.2579  0.2096
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0629  0.1056  0.1208
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1810  0.0976  0.0877
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1127  0.1034  0.1403
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2942  0.2570  0.2967
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3176  0.2590  0.3797
#
#                                                                             \
#                                                        t:1     t:2     t:3
# 01_GAN_evaluation_cycle5_idt5                       0.1031  0.0338  0.0822
# 02_GAN_evaluation_cycle5_idt5                       0.0674  0.0384  0.0602
# 03_GAN_evaluation_conventionalKL                    0.0127  0.0589  0.0300
# 03_GAN_evaluation_proposedKL                        0.1658  0.1926  0.2015
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0014  0.0057  0.0040
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1669  0.1384  0.1921
# 05_GAN_evaluation_gradattention_relu_0              0.2431  0.2387  0.3198
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2525  0.2707  0.3227
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2391  0.3360  0.3554
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1614  0.1745  0.2479
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1357  0.1797  0.2351
# 05_GAN_evaluation_gradattention_relumodified_at...  0.2121  0.1985  0.1947
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3540  0.2435  0.4344
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3861  0.3958  0.3951
#
#                                                        s:3                  \
#                                                        t:0     t:1     t:2
# 01_GAN_evaluation_cycle5_idt5                       0.0905  0.0657  0.0691
# 02_GAN_evaluation_cycle5_idt5                       0.0511  0.0383  0.0448
# 03_GAN_evaluation_conventionalKL                    0.0111  0.0185  0.0313
# 03_GAN_evaluation_proposedKL                        0.1218  0.1276  0.1781
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0028  0.0037  0.0056
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1647  0.1165  0.1585
# 05_GAN_evaluation_gradattention_relu_0              0.1748  0.1500  0.2558
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2018  0.1548  0.2636
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2108  0.1580  0.3217
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1086  0.0809  0.1645
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0816  0.0808  0.2002
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1705  0.1107  0.1878
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3063  0.2454  0.3140
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3392  0.2518  0.3856
#
#
#                                                        t:3
# 01_GAN_evaluation_cycle5_idt5                       0.0268
# 02_GAN_evaluation_cycle5_idt5                       0.0303
# 03_GAN_evaluation_conventionalKL                    0.0368
# 03_GAN_evaluation_proposedKL                        0.2058
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0050
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1335
# 05_GAN_evaluation_gradattention_relu_0              0.1932
# 05_GAN_evaluation_gradattention_relu_attention0...  0.1893
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2403
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1271
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0999
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0984
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2022
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.1941

# %%
fe = fe_list[2]
metric = "coverage"

columns = []
for i in classes:
    for j in classes:
        columns.append((f"s:{i}", f"t:{j}"))
columns = pd.MultiIndex.from_tuples(columns)

scores = []
for path in path_list:
    GAN_eval = pickle_load(path)
    for source_label in classes:
        for target_label in classes:
            scores.append(np.round(np.mean(GAN_eval[fe][source_label][target_label][metric]),4))
pd.DataFrame(np.array(scores).reshape(len(path_list),16), index=model_name, columns=columns)
# Out:
#                                                        s:0                  \
#                                                        t:0     t:1     t:2
# 01_GAN_evaluation_cycle5_idt5                       0.0335  0.0552  0.0709
# 02_GAN_evaluation_cycle5_idt5                       0.0324  0.0443  0.0414
# 03_GAN_evaluation_conventionalKL                    0.0401  0.0299  0.0168
# 03_GAN_evaluation_proposedKL                        0.1979  0.2142  0.1601
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0053  0.0041  0.0025
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1384  0.1701  0.1071
# 05_GAN_evaluation_gradattention_relu_0              0.1814  0.1901  0.1872
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2263  0.2000  0.2167
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2315  0.1860  0.3149
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1298  0.1038  0.0875
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0943  0.0871  0.1738
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1112  0.1170  0.1304
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2452  0.2538  0.2672
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3087  0.2894  0.3685
#
#                                                                s:1          \
#                                                        t:3     t:0     t:1
# 01_GAN_evaluation_cycle5_idt5                       0.1004  0.0572  0.0275
# 02_GAN_evaluation_cycle5_idt5                       0.0537  0.0462  0.0298
# 03_GAN_evaluation_conventionalKL                    0.0133  0.0386  0.0339
# 03_GAN_evaluation_proposedKL                        0.2132  0.1955  0.2132
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0011  0.0052  0.0053
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1760  0.1763  0.1353
# 05_GAN_evaluation_gradattention_relu_0              0.2994  0.1918  0.1556
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2628  0.2371  0.1595
# 05_GAN_evaluation_gradattention_relu_attention0...  0.3220  0.2552  0.1535
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1852  0.1534  0.0944
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1958  0.1111  0.0716
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1738  0.1495  0.0922
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3784  0.2964  0.1698
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3466  0.3266  0.1738
#
#                                                                        s:2  \
#                                                        t:2     t:3     t:0
# 01_GAN_evaluation_cycle5_idt5                       0.0750  0.0533  0.0826
# 02_GAN_evaluation_cycle5_idt5                       0.0458  0.0308  0.0325
# 03_GAN_evaluation_conventionalKL                    0.0078  0.0172  0.0148
# 03_GAN_evaluation_proposedKL                        0.1411  0.1894  0.1002
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0019  0.0029  0.0031
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1159  0.1178  0.1300
# 05_GAN_evaluation_gradattention_relu_0              0.1819  0.2146  0.1928
# 05_GAN_evaluation_gradattention_relu_attention0...  0.1415  0.1792  0.2119
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2795  0.2579  0.2096
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0629  0.1056  0.1208
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1810  0.0976  0.0877
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1127  0.1034  0.1403
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2942  0.2570  0.2967
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3176  0.2590  0.3797
#
#                                                                             \
#                                                        t:1     t:2     t:3
# 01_GAN_evaluation_cycle5_idt5                       0.1031  0.0338  0.0822
# 02_GAN_evaluation_cycle5_idt5                       0.0674  0.0384  0.0602
# 03_GAN_evaluation_conventionalKL                    0.0127  0.0589  0.0300
# 03_GAN_evaluation_proposedKL                        0.1658  0.1926  0.2015
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0014  0.0057  0.0040
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1669  0.1384  0.1921
# 05_GAN_evaluation_gradattention_relu_0              0.2431  0.2387  0.3198
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2525  0.2707  0.3227
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2391  0.3360  0.3554
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1614  0.1745  0.2479
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1357  0.1797  0.2351
# 05_GAN_evaluation_gradattention_relumodified_at...  0.2121  0.1985  0.1947
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3540  0.2435  0.4344
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3861  0.3958  0.3951
#
#                                                        s:3                  \
#                                                        t:0     t:1     t:2
# 01_GAN_evaluation_cycle5_idt5                       0.0905  0.0657  0.0691
# 02_GAN_evaluation_cycle5_idt5                       0.0511  0.0383  0.0448
# 03_GAN_evaluation_conventionalKL                    0.0111  0.0185  0.0313
# 03_GAN_evaluation_proposedKL                        0.1218  0.1276  0.1781
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0028  0.0037  0.0056
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1647  0.1165  0.1585
# 05_GAN_evaluation_gradattention_relu_0              0.1748  0.1500  0.2558
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2018  0.1548  0.2636
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2108  0.1580  0.3217
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1086  0.0809  0.1645
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0816  0.0808  0.2002
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1705  0.1107  0.1878
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.3063  0.2454  0.3140
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.3392  0.2518  0.3856
#
#
#                                                        t:3
# 01_GAN_evaluation_cycle5_idt5                       0.0268
# 02_GAN_evaluation_cycle5_idt5                       0.0303
# 03_GAN_evaluation_conventionalKL                    0.0368
# 03_GAN_evaluation_proposedKL                        0.2058
# 03_GAN_evaluation_styleINdataset_conventionalKL     0.0050
# 03_GAN_evaluation_styleINdataset_proposedKL         0.1335
# 05_GAN_evaluation_gradattention_relu_0              0.1932
# 05_GAN_evaluation_gradattention_relu_attention0...  0.1893
# 05_GAN_evaluation_gradattention_relu_attention0...  0.2403
# 05_GAN_evaluation_gradattention_relumodified_at...  0.1271
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0999
# 05_GAN_evaluation_gradattention_relumodified_at...  0.0984
# 05_GAN_evaluation_pretrained_relu_attention0_co...  0.2022
# 05_GAN_evaluation_pretrained_relumodified_atten...  0.1941
